# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Data.csv")

# %%
df
# Out:
#       Unnamed: 0      Order ID  Order Date Port of Origin Transporter  \
# 0              0  1.447296e+09  2013-05-26         PORT09       V44_3
# 1              1  1.447158e+09  2013-05-26         PORT09       V44_3
# 2              2  1.447139e+09  2013-05-26         PORT09       V44_3
# 3              3  1.447364e+09  2013-05-26         PORT09       V44_3
# 4              4  1.447364e+09  2013-05-26         PORT09       V44_3
# ...          ...           ...         ...            ...         ...
# 9210        9210  1.447305e+09  2013-05-26         PORT04      V444_1
# 9211        9211  1.447319e+09  2013-05-26         PORT04      V444_1
# 9212        9212  1.447322e+09  2013-05-26         PORT04      V444_1
# 9213        9213  1.447145e+09  2013-05-26         PORT04      V444_1
# 9214        9214  1.447328e+09  2013-05-26         PORT04      V444_1
#
#       Throughput time Service Level  Day count for shipping ahead  \
# ...

# %%
print(df.groupby('Service Level').mean()) 
a=df['Service Level']
b=df['Weight']
# Out:
#                 Unnamed: 0      Order ID  Throughput time  \
# Service Level
# CRF             426.500000  1.447292e+09         1.289227
# DTD            8138.986001  1.447275e+09         1.088194
# DTP            3963.883403  1.447271e+09         1.993567
#
#                Day count for shipping ahead  Ship Late Day count  \
# Service Level
# CRF                                2.019906             0.000000
# DTD                                2.280915             0.012599
# DTP                                1.681570             0.054841
#
#                  Product ID  The number of units     Weight
# Service Level
# CRF            1.693069e+06          4462.395785  41.103810
# DTD            1.683729e+06          1294.377508  12.946981
# DTP            1.677714e+06          3687.452235  19.342162

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df.groupby('Service Level', as_index=False)['Weight'].mean()


# plot
p = sns.barplot('Service Level', 'Weight', data=df, ci=False).set(title='The graph shows average Weights for each Service Levels')
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# So for CRF Service level, average Weight is - 40
# For DTP - average Weight is - approximately 18
# For DTD - approximately 13

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df.groupby('Service Level', as_index=False)['Day count for shipping ahead'].mean()


# plot
p = sns.barplot('Service Level', 'Day count for shipping ahead', data=df, ci=False).set(title='The graph shows average Day count for shipping ahead for each Service Levels')
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
